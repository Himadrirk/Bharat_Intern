# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("realest.csv")
data
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# ..     ...      ...     ...   ...   ...     ...       ...     ...        ...
# 152   44.0      3.0   820.0   5.0  27.0     NaN       1.0     0.0        1.0
# 153   43.0      2.0   593.0   4.0  30.0   465.0       2.0     1.0        0.0
# 154   53.0      3.0   716.0   6.0  30.0   585.0       1.0     2.0        1.0
# 155   62.0      4.0   951.0   7.0  30.0   895.0       2.0     1.0        0.0
# 156    NaN      NaN     NaN   NaN   NaN     NaN       NaN     NaN        NaN
#
# [157 rows x 9 columns]

# %%
data.head()
# Out:
#    Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0   53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1   55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2   56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3   58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4   64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0

# %%
data.shape
# Out:
# (157, 9)

# %%
data.size
# Out:
# 1413

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      156 non-null    float64
#  1   Bedroom    156 non-null    float64
#  2   Space      146 non-null    float64
#  3   Room       156 non-null    float64
#  4   Lot        146 non-null    float64
#  5   Tax        147 non-null    float64
#  6   Bathroom   156 non-null    float64
#  7   Garage     156 non-null    float64
#  8   Condition  156 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
data.dropna(inplace = True)
data
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# ..     ...      ...     ...   ...   ...     ...       ...     ...        ...
# 149   32.0      4.0  1065.0   7.0  25.0   492.0       1.5     0.0        0.0
# 151   42.0      3.0   585.0   5.0  50.0   713.0       1.0     0.0        0.0
# 153   43.0      2.0   593.0   4.0  30.0   465.0       2.0     1.0        0.0
# 154   53.0      3.0   716.0   6.0  30.0   585.0       1.0     2.0        1.0
# 155   62.0      4.0   951.0   7.0  30.0   895.0       2.0     1.0        0.0
#
# [128 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      128 non-null    float64
#  1   Bedroom    128 non-null    float64
#  2   Space      128 non-null    float64
#  3   Room       128 non-null    float64
#  4   Lot        128 non-null    float64
#  5   Tax        128 non-null    float64
#  6   Bathroom   128 non-null    float64
#  7   Garage     128 non-null    float64
#  8   Condition  128 non-null    float64
# dtypes: float64(9)
# memory usage: 10.0 KB

# %%
data.describe()
# Out:
#             Price     Bedroom        Space        Room         Lot  \
# count  128.000000  128.000000   128.000000  128.000000  128.000000
# mean    56.718750    3.195312  1109.382812    6.531250   32.664062
# std     13.348708    1.392096   480.844011    1.724933    8.630907
# min     32.000000    1.000000   539.000000    4.000000   24.000000
# 25%     46.000000    2.000000   809.750000    5.000000   25.000000
# 50%     56.000000    3.000000   963.500000    6.000000   30.000000
# 75%     64.000000    4.000000  1199.500000    7.000000   35.500000
# max     90.000000    8.000000  2295.000000   12.000000   50.000000
#
#                Tax    Bathroom      Garage   Condition
# count   128.000000  128.000000  128.000000  128.000000
# mean    925.476562    1.488281    0.812500    0.226562
# std     435.174559    0.548674    0.810852    0.420252
# min     418.000000    1.000000    0.000000    0.000000
# 25%     679.750000    1.000000    0.000000    0.000000
# 50%     855.500000    1.500000    1.000000    0.000000
# 75%    1039.750000    2.000000    1.500000    0.000000
# max    2752.000000    3.000000    2.000000    1.000000

# %%
data.columns
# Out:
# Index(['Price', 'Bedroom', 'Space', 'Room', 'Lot', 'Tax', 'Bathroom', 'Garage',
#        'Condition'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis for House Price Prediction

# %%
sns.pairplot(data)
plt.show
# Out:
# C:\Users\himad\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['Bedroom'].value_counts().plot(kind='bar')
plt.title('Bedroom')
plt.xlabel('Bedroom')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.histplot(data['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Train Test Split

# %%
data.columns
# Out:
# Index(['Price', 'Bedroom', 'Space', 'Room', 'Lot', 'Tax', 'Bathroom', 'Garage',
#        'Condition'],
#       dtype='object')

# %%
x = data[['Bedroom','Space','Room','Lot','Tax','Bathroom','Garage','Condition']]

# %%
y = data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=101)

# %% [markdown]
# # Training a model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 18.41206168056427

# %%
lm.coef_
# Out:
# array([-3.45924009e+00,  1.42153871e-02,  1.18175791e+00,  4.77586722e-01,
#        -1.07924140e-04,  3.67773659e+00,  4.64154214e+00,  1.32771471e+00])

# %%
X_train.columns
# Out:
# Index(['Bedroom', 'Space', 'Room', 'Lot', 'Tax', 'Bathroom', 'Garage',
#        'Condition'],
#       dtype='object')

# %%
coeff_data = pd.DataFrame(lm.coef_,x.columns,columns=['Coefficient'])
coeff_data
# Out:
#            Coefficient
# Bedroom      -3.459240
# Space         0.014215
# Room          1.181758
# Lot           0.477587
# Tax          -0.000108
# Bathroom      3.677737
# Garage        4.641542
# Condition     1.327715

# %% [markdown]
# # Predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([46.40602932, 44.9865737 , 67.18641848, 78.43567559, 51.04227434,
#        39.56194078, 56.08062262, 58.6600751 , 37.8532883 , 58.92888481,
#        38.7711223 , 52.70913537, 37.75226966, 42.53849955, 43.67408214,
#        55.99835218, 58.43518871, 76.7512004 , 81.3698436 , 57.07647305,
#        43.1055647 , 62.93403067, 44.04619967, 83.68281672, 56.25938776,
#        56.19261893, 52.59426471, 53.15776816, 37.7310698 , 50.92476995,
#        63.40507505, 52.54372409, 50.55910692, 84.80785322, 73.78531969,
#        49.73925521, 52.88122396, 55.24474589, 58.83627229, 54.07149152,
#        55.59751531, 85.06534905, 54.8903634 , 52.7659286 , 53.24441433,
#        53.85610767, 69.28932025, 47.40071647, 53.5138537 , 57.50649615,
#        37.77468728, 43.67644659])

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot: Actual vs. Predicted')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
from sklearn import metrics

# %%
print(len(y_test))
print(len(predictions))
if len(y_test) != len(predictions):
    raise ValueError("Number of samples in y_test and predictions don't match!")
mae = metrics.mean_absolute_error(y_test, predictions)
print('MAE:', mae)
mse = metrics.mean_squared_error(y_test, predictions)
print('MSE:', mse)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Out:
# 26
# 52
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[158], line 4
#       2 print(len(predictions))
#       3 if len(y_test) != len(predictions):
# ----> 4     raise ValueError("Number of samples in y_test and predictions don't match!")
#       5 mae = metrics.mean_absolute_error(y_test, predictions)
#       6 print('MAE:', mae)
#
# ValueError: Number of samples in y_test and predictions don't match!
